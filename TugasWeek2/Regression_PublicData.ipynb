# %% [markdown]
# <a href="https://colab.research.google.com/github/pratyenggodip/MachineLearningTask/blob/main/TugasWeek2/Regression_PublicData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   Nama : Pratyenggo Damar Iswara Putra
# *   NIM  : 1103194141
# *   Tugas 2

# %%
# Impor library yang diperlukan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Connect google collab with google drive
from google.colab import drive
drive.mount ('/content/drive')

# File path in Google Drive
file_path = '/content/drive/MyDrive/DATASET/insurance.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# Memilih fitur (independent variable) dan target (dependent variable)
# Gantilah 'fitur' dan 'target' sesuai dengan kolom yang sesuai di dataset
fitur = df[['age', 'bmi', 'children']]
target = df['expenses']  # Mengganti target ke kolom 'expenses'

# Membagi dataset menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(fitur, target, test_size=0.2, random_state=42)

# Menerapkan Regresi Linier
model = LinearRegression()
model.fit(X_train, y_train)

# Membuat prediksi pada data uji
y_pred = model.predict(X_test)

# Evaluasi model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')

# Visualisasi hasil
plt.scatter(X_test['age'], y_test, color='black', label='Actual Data')
plt.scatter(X_test['age'], y_pred, color='red', label='Predicted Data')
plt.title('Regresi Linier pada Dataset Asuransi (expenses)')
plt.xlabel('Umur')
plt.ylabel('Biaya Asuransi')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 131188609.80827309
# R-squared: 0.1549779076526725
